# %%
import numpy as np
import pandas as pd

# %%
df_data = pd.read_csv('ANTM.JK.csv')
df_data.head(7)
# Out:
#          Date    Open    High     Low   Close  Adj Close     Volume
# 0  2022-06-15  2180.0  2240.0  2120.0  2170.0     2170.0   94872500
# 1  2022-06-16  2200.0  2230.0  2140.0  2150.0     2150.0   99487000
# 2  2022-06-17  2120.0  2140.0  2100.0  2110.0     2110.0   70818600
# 3  2022-06-20  2110.0  2130.0  2050.0  2070.0     2070.0   78282700
# 4  2022-06-21  2080.0  2150.0  2070.0  2150.0     2150.0   83298700
# 5  2022-06-22  2140.0  2140.0  2020.0  2020.0     2020.0  171508200
# 6  2022-06-23  2020.0  2020.0  1955.0  1965.0     1965.0  127468500

# %%
df_data.shape
# Out:
# (247, 7)

# %%
df_data.plot(x= 'Date', y='Close')
# Out:
# <Axes: xlabel='Date'>

# %%
X = df_data[['Open', 'High', 'Low']]  # Fitur: Open, High, Low
y = df_data['Close']  # Target: Close

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_absolute_percentage_error

scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
# Membuat model KNN
knn = KNeighborsRegressor(n_neighbors=5)

# %%
# Melatih model menggunakan train set
knn.fit(X_train, y_train)
# Out:
# KNeighborsRegressor()

# %%
# Melakukan prediksi pada test set
y_pred = knn.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_percentage_error

# Menghitung MAPE
mape = mean_absolute_percentage_error(y_test, y_pred)
print("Mean Absolute Percentage Error (MAPE):", mape)
# Out:
# Mean Absolute Percentage Error (MAPE): 0.011435685997526543

# %%
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error (MSE):", mse)
# Out:
# Mean Squared Error (MSE): 937.24
